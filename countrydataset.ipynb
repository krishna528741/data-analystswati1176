# %%
import pandas as pd
import numpy as np
import statistics 
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
from scipy import stats
warnings.filterwarnings("ignore")
import gmpy2

# %%
data =pd.read_csv("factbook.csv")

# %%
data
# Out:
#             Country  Area(sq km)  Birth rate(births/1000 population)  \
# 0       Afghanistan       647500                                47.0
# 1          Akrotiri          123                                 NaN
# 2           Albania        28748                                15.0
# 3           Algeria      2381740                                17.0
# 4    American Samoa          199                                23.0
# ..              ...          ...                                 ...
# 258       West Bank         5860                                32.0
# 259  Western Sahara       266000                                 NaN
# 260           Yemen       527970                                43.0
# 261          Zambia       752614                                41.0
# 262        Zimbabwe       390580                                30.0
#
#      Current account balance  Death rate(deaths/1000 population)  \
# 0                        NaN                                21.0
# ...

# %%
data.dtypes
# Out:
# Country                                            object
# Area(sq km)                                         int64
# Birth rate(births/1000 population)                float64
# Current account balance                           float64
# Death rate(deaths/1000 population)                float64
# Debt - external                                   float64
# Electricity - consumption(kWh)                    float64
# Electricity - production(kWh)                     float64
# Exports                                           float64
# GDP                                               float64
# GDP - per capita                                  float64
# GDP - real growth rate(%)                          object
# HIV/AIDS - adult prevalence rate(%)               float64
# HIV/AIDS - deaths                                 float64
# HIV/AIDS - people living with HIV/AIDS            float64
# Highways(km)                                      float64
# ...

# %%
data.isnull()
# Out:
#      Country  Area(sq km)  Birth rate(births/1000 population)  \
# 0      False        False                               False
# 1      False        False                                True
# 2      False        False                               False
# 3      False        False                               False
# 4      False        False                               False
# ..       ...          ...                                 ...
# 258    False        False                               False
# 259    False        False                                True
# 260    False        False                               False
# 261    False        False                               False
# 262    False        False                               False
#
#      Current account balance  Death rate(deaths/1000 population)  \
# 0                       True                               False
# 1                       True                                True
# ...

# %%
data.drop("Unnamed: 45",axis=1,inplace=True)

# %%
data

# %%
data.fillna(data.mean(),inplace=True)

# %%
data

# %%
data.describe()

# %%
data.loc[:, ["Country","Area(sq km)","Reserves of foreign exchange & gold"]]

# %% [markdown]
# # we just save the above clean data so that i can change the dtypes of scientific notation to int type

# %%
country=pd.read_csv("newdata.csv") # new as i have many columsn which i wan t o convert in to int so i change its before uploading in pandas

# %%
country

# %%
country.drop("Unnamed: 45",axis=1,inplace=True)

# %%
country

# %%
country.dtypes

# %%
data.loc[:, ["Country","Area(sq km)","Reserves of foreign exchange & gold"]]

# %%
# Assuming 'Country' is the name of the column that contains country names
max_value_index = country['Reserves of foreign exchange & gold'].idxmax()
max_country = country.loc[max_value_index, 'Country']
max_value = country.loc[max_value_index, 'Reserves of foreign exchange & gold']
print("The country with the highest reserves of foreign exchange & gold is", max_country, "with a value of", max_value)

# %% [markdown]
# # groupby to show forex reserve across country name

# %%
max_reserve = country.groupby('Country')['Reserves of foreign exchange & gold'].max()
print (max_reserve)

# %% [markdown]
# # top 10 highest forex reserve holding countries

# %%
# Select top 10 rows by forex reserves
top_10 = country.nlargest(10, 'Reserves of foreign exchange & gold')

# %%
 top_10.groupby('Country')['Reserves of foreign exchange & gold'].max()

# %% [markdown]
# # highest forex reserve holding country

# %%
top_reserve = country.nlargest(1, 'Reserves of foreign exchange & gold')
top_reserve.groupby("Country")["Reserves of foreign exchange & gold"].max()

# %% [markdown]
# # top 10 area wise countries #nlargest

# %%
top_10 = country.nlargest(10, 'Area(sq km)')

# %%
 top_10.groupby('Country')['Area(sq km)'].max()

# %% [markdown]
# # largest populated country

# %%
top=country.nlargest(1,"Population") 
top.groupby("Country")["Population"].max()

# %% [markdown]
# # highest electricity consuming country

# %%
highest_elect =country.nlargest(1,"Electricity - consumption(kWh)") 
highest_elect.groupby("Country")["Electricity - consumption(kWh)"].max()

# %% [markdown]
# # highest producer of electricity

# %%
highest_producer =country.nlargest(1,"Electricity - production(kWh)") 
highest_producer.groupby("Country")["Electricity - production(kWh)"].max()

# %% [markdown]
# # lowest 10 countries in area

# %%
low_10 = country.nsmallest(10, 'Area(sq km)')
low_10.groupby('Country')['Area(sq km)'].max()

# %% [markdown]
# # lowest forex reserve holding country

# %%
low_reserve = country.nsmallest(1, 'Reserves of foreign exchange & gold')
low_reserve.groupby("Country")["Reserves of foreign exchange & gold"].min()

# %% [markdown]
# # least populated country

# %%
low_population=country.nsmallest(1,"Population") 
low_population.groupby("Country")["Population"].min()

# %% [markdown]
# # lowest electricity producing country

# %%
lowest_elect =country.nsmallest(1,"Electricity - production(kWh)") 
lowest_elect.groupby("Country")["Electricity - production(kWh)"].min()

# %% [markdown]
# # lowest electricity producing country

# %%
lowest_electconsumption =country.nsmallest(1,"Electricity - consumption(kWh)") 
lowest_electconsumption .groupby("Country")["Electricity - consumption(kWh)"].min()

# %% [markdown]
# # highest and lowest unemployment rate

# %%
highest_unemp=country.nlargest(1,"Unemployment rate(%)")
highest_unemp.groupby("Country")["Unemployment rate(%)"].max()

# %%
lowest_unemp=country.nsmallest(1,"Unemployment rate(%)")
lowest_unemp.groupby("Country")["Unemployment rate(%)"].min()
