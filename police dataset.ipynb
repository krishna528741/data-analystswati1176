# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statistics
import warnings 
warnings.filterwarnings("ignore")
from scipy import stats

# %%
police=pd.read_csv("Police Data.csv")

# %%
police  #nan means there ins null value present in this will remove this
# Out:
#         stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 0      01/02/2005      1:55           NaN             M          1985.0
# 1      18/01/2005      8:15           NaN             M          1965.0
# 2       1/23/2005     23:15           NaN             M          1972.0
# 3       2/20/2005     17:15           NaN             M          1986.0
# 4       3/14/2005     10:00           NaN             F          1984.0
# ...           ...       ...           ...           ...             ...
# 65530  12/06/2012     17:54           NaN             F          1987.0
# 65531  12/06/2012     22:22           NaN             M          1954.0
# 65532  12/06/2012     23:20           NaN             M          1985.0
# 65533  12/07/2012      0:23           NaN           NaN             NaN
# 65534  12/07/2012      0:30           NaN             F          1985.0
#
#        driver_age driver_race                   violation_raw  violation  \
# ...

# %%
police.head()
# Out:
#     stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 0  01/02/2005      1:55           NaN             M          1985.0
# 1  18/01/2005      8:15           NaN             M          1965.0
# 2   1/23/2005     23:15           NaN             M          1972.0
# 3   2/20/2005     17:15           NaN             M          1986.0
# 4   3/14/2005     10:00           NaN             F          1984.0
#
#    driver_age driver_race     violation_raw violation  search_conducted  \
# 0        20.0       White          Speeding  Speeding             False
# 1        40.0       White          Speeding  Speeding             False
# 2        33.0       White          Speeding  Speeding             False
# 3        19.0       White  Call for Service     Other             False
# 4        21.0       White          Speeding  Speeding             False
#
#   search_type   stop_outcome is_arrested stop_duration  drugs_related_stop
# ...

# %%
police.tail()
# Out:
#         stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 65530  12/06/2012     17:54           NaN             F          1987.0
# 65531  12/06/2012     22:22           NaN             M          1954.0
# 65532  12/06/2012     23:20           NaN             M          1985.0
# 65533  12/07/2012      0:23           NaN           NaN             NaN
# 65534  12/07/2012      0:30           NaN             F          1985.0
#
#        driver_age driver_race                   violation_raw  violation  \
# 65530        25.0       White                        Speeding   Speeding
# 65531        58.0       White                        Speeding   Speeding
# 65532        27.0       Black  Equipment/Inspection Violation  Equipment
# 65533         NaN         NaN                             NaN        NaN
# 65534        27.0       White                        Speeding   Speeding
#
#        search_conducted search_type stop_outcome is_arrested stop_duration  \
# ...

# %%
police.dtypes
# Out:
# stop_date              object
# stop_time              object
# country_name          float64
# driver_gender          object
# driver_age_raw        float64
# driver_age            float64
# driver_race            object
# violation_raw          object
# violation              object
# search_conducted         bool
# search_type            object
# stop_outcome           object
# is_arrested            object
# stop_duration          object
# drugs_related_stop       bool
# dtype: object

# %%
police.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65535 entries, 0 to 65534
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           65535 non-null  object
#  1   stop_time           65535 non-null  object
#  2   country_name        0 non-null      float64
#  3   driver_gender       61474 non-null  object
#  4   driver_age_raw      61481 non-null  float64
#  5   driver_age          61228 non-null  float64
#  6   driver_race         61475 non-null  object
#  7   violation_raw       61475 non-null  object
#  8   violation           61475 non-null  object
#  9   search_conducted    65535 non-null  bool
#  10  search_type         2479 non-null   object
#  11  stop_outcome        61475 non-null  object
#  12  is_arrested         61475 non-null  object
#  13  stop_duration       61475 non-null  object
#  14  drugs_related_stop  65535 non-null  bool
# ...

# %%
police.describe()
# Out:
#        country_name  driver_age_raw    driver_age
# count           0.0    61481.000000  61228.000000
# mean            NaN     1967.791106     34.148984
# std             NaN      121.050106     12.760710
# min             NaN        0.000000     15.000000
# 25%             NaN     1965.000000     23.000000
# 50%             NaN     1978.000000     31.000000
# 75%             NaN     1985.000000     43.000000
# max             NaN     8801.000000     88.000000

# %% [markdown]
# # data cleaning

# %%
police.isnull() # country_name ,search _type showing true it means its null vallue
# Out:
#        stop_date  stop_time  country_name  driver_gender  driver_age_raw  \
# 0          False      False          True          False           False
# 1          False      False          True          False           False
# 2          False      False          True          False           False
# 3          False      False          True          False           False
# 4          False      False          True          False           False
# ...          ...        ...           ...            ...             ...
# 65530      False      False          True          False           False
# 65531      False      False          True          False           False
# 65532      False      False          True          False           False
# 65533      False      False          True           True            True
# 65534      False      False          True          False           False
#
#        driver_age  driver_race  violation_raw  violation  search_conducted  \
# ...

# %%
police.isnull().sum()  # total number of null value in all columns
# Out:
# stop_date                 0
# stop_time                 0
# country_name          65535
# driver_gender          4061
# driver_age_raw         4054
# driver_age             4307
# driver_race            4060
# violation_raw          4060
# violation              4060
# search_conducted          0
# search_type           63056
# stop_outcome           4060
# is_arrested            4060
# stop_duration          4060
# drugs_related_stop        0
# dtype: int64

# %%
police.drop(columns= "country_name",inplace =True)

# %%
police
# Out:
#         stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0      01/02/2005      1:55             M          1985.0        20.0
# 1      18/01/2005      8:15             M          1965.0        40.0
# 2       1/23/2005     23:15             M          1972.0        33.0
# 3       2/20/2005     17:15             M          1986.0        19.0
# 4       3/14/2005     10:00             F          1984.0        21.0
# ...           ...       ...           ...             ...         ...
# 65530  12/06/2012     17:54             F          1987.0        25.0
# 65531  12/06/2012     22:22             M          1954.0        58.0
# 65532  12/06/2012     23:20             M          1985.0        27.0
# 65533  12/07/2012      0:23           NaN             NaN         NaN
# 65534  12/07/2012      0:30             F          1985.0        27.0
#
#       driver_race                   violation_raw  violation  \
# 0           White                        Speeding   Speeding
# ...

# %%
police.drop(columns= "search_type",inplace =True)

# %%
police
# Out:
#         stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0      01/02/2005      1:55             M          1985.0        20.0
# 1      18/01/2005      8:15             M          1965.0        40.0
# 2       1/23/2005     23:15             M          1972.0        33.0
# 3       2/20/2005     17:15             M          1986.0        19.0
# 4       3/14/2005     10:00             F          1984.0        21.0
# ...           ...       ...           ...             ...         ...
# 65530  12/06/2012     17:54             F          1987.0        25.0
# 65531  12/06/2012     22:22             M          1954.0        58.0
# 65532  12/06/2012     23:20             M          1985.0        27.0
# 65533  12/07/2012      0:23           NaN             NaN         NaN
# 65534  12/07/2012      0:30             F          1985.0        27.0
#
#       driver_race                   violation_raw  violation  \
# 0           White                        Speeding   Speeding
# ...

# %%
police.dropna(inplace=True) #remaining null value has been removed,now dataset has 13 columns as we removed 2 columns already

# %% [markdown]
# # how many times men ,women stopped for speeding

# %%
police
# Out:
#         stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0      01/02/2005      1:55             M          1985.0        20.0
# 1      18/01/2005      8:15             M          1965.0        40.0
# 2       1/23/2005     23:15             M          1972.0        33.0
# 3       2/20/2005     17:15             M          1986.0        19.0
# 4       3/14/2005     10:00             F          1984.0        21.0
# ...           ...       ...           ...             ...         ...
# 65529  12/06/2012     16:00             M          1994.0        18.0
# 65530  12/06/2012     17:54             F          1987.0        25.0
# 65531  12/06/2012     22:22             M          1954.0        58.0
# 65532  12/06/2012     23:20             M          1985.0        27.0
# 65534  12/07/2012      0:30             F          1985.0        27.0
#
#       driver_race                   violation_raw  violation  \
# 0           White                        Speeding   Speeding
# ...

# %%
police[police.violation_raw == "Speeding"].driver_gender.value_counts()
# Out:
# M    25458
# F    11661
# Name: driver_gender, dtype: int64

# %%
police[police.violation_raw == "Speeding"].driver_race.value_counts()
# Out:
# White       30119
# Black        3647
# Hispanic     2056
# Asian        1172
# Other         125
# Name: driver_race, dtype: int64

# %%
police[police.violation == "Moving violation"].driver_gender.value_counts()
# Out:
# M    9739
# F    2137
# Name: driver_gender, dtype: int64

# %%
police[police.violation == "Registration/plates"].driver_gender.value_counts()
police[police.violation == "Registration/plates"].driver_race.value_counts()
# Out:
# White       1241
# Black        502
# Hispanic     467
# Asian         29
# Other          1
# Name: driver_race, dtype: int64

# %% [markdown]
# # does specific gender searched during stop?

# %%
police.groupby("driver_gender").search_conducted.sum()
# Out:
# driver_gender
# F     366
# M    2111
# Name: search_conducted, dtype: int64

# %%
police.search_conducted.value_counts()
# Out:
# False    58745
# True      2477
# Name: search_conducted, dtype: int64

# %% [markdown]
# # Mean of stop_duration byt data type of this columns is string we have to convert it into integer to find its mean

# %%
police.dtypes
# Out:
# stop_date              object
# stop_time              object
# driver_gender          object
# driver_age_raw        float64
# driver_age            float64
# driver_race            object
# violation_raw          object
# violation              object
# search_conducted         bool
# stop_outcome           object
# is_arrested            object
# stop_duration          object
# drugs_related_stop       bool
# dtype: object

# %%
police.stop_duration.value_counts()  # we have time in the form of interval forms then we have to change the
                                        #data type by following ways
# Out:
# 0-15 Min     47202
# 16-30 Min    11377
# 30+ Min       2642
# 2                1
# Name: stop_duration, dtype: int64

# %%
police["stop_duration"]= police['stop_duration'].map({'0-15 Min':7.5, "16-30 Min ":24,"30+ Min" : 45})

# %%
police
# Out:
#         stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0      01/02/2005      1:55             M          1985.0        20.0
# 1      18/01/2005      8:15             M          1965.0        40.0
# 2       1/23/2005     23:15             M          1972.0        33.0
# 3       2/20/2005     17:15             M          1986.0        19.0
# 4       3/14/2005     10:00             F          1984.0        21.0
# ...           ...       ...           ...             ...         ...
# 65529  12/06/2012     16:00             M          1994.0        18.0
# 65530  12/06/2012     17:54             F          1987.0        25.0
# 65531  12/06/2012     22:22             M          1954.0        58.0
# 65532  12/06/2012     23:20             M          1985.0        27.0
# 65534  12/07/2012      0:30             F          1985.0        27.0
#
#       driver_race                   violation_raw  violation  \
# 0           White                        Speeding   Speeding
# ...

# %%
police["stop_duration"].mean()
# Out:
# 9.487701629082737

# %% [markdown]
# # compare age distribution for each violation

# %%
police.groupby('violation').driver_age_raw.describe()
# Out:
#                        count         mean        std     min     25%     50%  \
# violation
# Equipment             6507.0  1978.056554  11.491006  1925.0  1971.0  1981.0
# Moving violation     11876.0  1972.725413  13.430315  1923.0  1963.0  1975.0
# Other                 3477.0  1969.013230  12.711857  1925.0  1960.0  1969.0
# Registration/plates   2240.0  1976.329464  11.175622  1937.0  1969.0  1979.0
# Seat belt                3.0  1981.666667  10.214369  1970.0  1978.0  1986.0
# Speeding             37119.0  1975.043724  12.731950  1918.0  1966.0  1979.0
#
#                         75%     max
# violation
# Equipment            1987.0  1995.0
# Moving violation     1984.0  1996.0
# Other                1980.0  1995.0
# Registration/plates  1985.0  1996.0
# Seat belt            1987.5  1989.0
# Speeding             1985.0  1996.0

# %%
police.groupby('violation_raw').driver_age_raw.describe()
# Out:
#                                     count         mean        std     min  \
# violation_raw
# APB                                  50.0  1973.000000  11.712543  1934.0
# Call for Service                    786.0  1975.083969  13.297309  1925.0
# Equipment/Inspection Violation     6507.0  1978.056554  11.491006  1925.0
# Motorist Assist/Courtesy            127.0  1972.708661  12.281170  1942.0
# Other Traffic Violation           11876.0  1972.725413  13.430315  1923.0
# Registration Violation             2240.0  1976.329464  11.175622  1937.0
# Seatbelt Violation                    3.0  1981.666667  10.214369  1970.0
# Special Detail/Directed Patrol     2298.0  1966.158834  11.569687  1932.0
# Speeding                          37119.0  1975.043724  12.731950  1918.0
# Suspicious Person                    36.0  1977.111111  12.910190  1943.0
# Violation of City/Town Ordinance    170.0  1973.547059  12.322137  1942.0
# ...
